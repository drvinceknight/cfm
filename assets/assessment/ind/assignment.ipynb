# %% [markdown]
# ### Computing for Mathematics - Individual coursework
#
# **Important** Do not delete the markdown cells containing the questions. Write your solutions in the cells directly underneath the relevant questions.

# %% [markdown]
# ## Question 1
#
# Consider $2 x^2 + yx = y + 1$. Find the solution to this equation for $x$. Obtain the specific solution when $y = -1$.
#
# *Solution*:

# %% [markdown]
# ## Question 2
#
# Let $f''(x) = x$. Find $f(x)$ when $f'(2) = -1$ and $f(0) = 2$.
#
# *Solution*:

# %% [markdown]
# ## Question 3
#
# By using matrices, solve the following system of linear equations:
#
# $$
# \begin{align*}
# x + y + x &= 2 \\
# x + 2y + 3z &= 1 \\
# 3x + z &= 5
# \end{align*}
# $$
#
# *Solution*:

# %% [markdown]
# ## Question 4
#
# Show by both enumerating and calculating directly, that the number of ways to arrange the letters of the word ```MICROBE``` such that the first three letters contain only vowels (the vowels in English are `A`, `E`, `I`, `O`, and `U`), is equal to ${}^3P_3 \times {}^4P_4$.
#
# *Solution*:

# %% [markdown]
# ## Question 5
#
# An event $A$ occurs with probability $2 / 7$, and an event $B$ occurs with probability $5 / 12$. Define functions for each event that simulates its occurance.
#
# An event $C$ is defined as either $A$ or $B$ occuring, but not both. Define a function that simulates the event $C$.
#
# Use this function repeatedly 10,000 times to find and estimate for the probability of $C$.
#
# *Solution*:

# %% [markdown]
# ## Question 6
#
# Consider a sequence defined recursively by
#
# $$
# G_n = \begin{cases}
# 1 & \text{if } n = 0,\\
# 1 & \text{if } n = 1, \\
# \sqrt{2 G_{n-1} + G_{n-2}} & \text{if } n > 1
# \end{cases}
# $$
#
# Write a recursive function for $G_n$, and use it to find the first 6 elements of the sequence.
#
# *Solution*:

# %% [markdown]
# ## Question 7
#
# FlexCoach run bus journeys between Cardiff and London 6 times a day, 7 days a week. The journey times are known to follow a Normal distribution with mean 220 minutes and standard deviation 35 minutes. FlexCoach guarantee to reimburse the price of the ticket if the journey takes more than 5 hours. How many journeys per week would they expect to have to reimburse the ticket price for?
#
# *Solution*:

# %% [markdown]
# ## Question 8
#
# Find the solution to the initial value problem $\frac{dy}{dx} = 3y^2x$ with $y(0) = 2$.
#
# *Solution*:
