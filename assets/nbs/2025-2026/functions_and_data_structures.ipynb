# %%
def x_cubed(x):
    """
    This takes an x and return x ^ 3.

    For example for x = 2 this would give 8.

    Parameters
    ----------
    x : float

    Returns
    -------
    float
    """
    return x ** 3

# %%
a_collection_that_does_not_change = (17, 13, 1, 2, 5)
a_collection_that_does_not_change
# Out:
# (17, 13, 1, 2, 5)

# %%
a_collection_that_does_change = [1, 2, "juliette"]
a_collection_that_does_change
# Out:
# [1, 2, 'juliette']

# %%
favourite_ever_students = ["Amarjit", ]
favourite_ever_students
# Out:
# ['Amarjit']

# %%
a_collection_that_does_change.append("Riggins")

# %%
a_collection_that_does_change
# Out:
# [1, 2, 'juliette', 'Riggins']

# %%
a_collection_that_does_change + favourite_ever_students
# Out:
# [1, 2, 'juliette', 'Riggins', 'Amarjit']

# %%
a_collection_that_does_change.remove("juliette")

# %%
a_collection_that_does_change
# Out:
# [1, 2, 'Riggins']

# %%
a_collection_that_does_change.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a_collection_that_does_change.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
a_collection_that_does_change
# Out:
# [1, 2, 'Riggins']

# %%
favourite_ever_students.append("Miayan")

# %%
favourite_ever_students.append("AAAAAAA")

# %%
favourite_ever_students
# Out:
# ['Amarjit', 'Miayan', 'AAAAAAA']

# %%
favourite_ever_students.sort()

# %%
favourite_ever_students
# Out:
# ['AAAAAAA', 'Amarjit', 'Miayan']

# %%
ordered_numbers = sorted(a_collection_that_does_not_change)

# %%
a_collection_that_does_not_change
# Out:
# (17, 13, 1, 2, 5)

# %%
favourite_ever_students[-2]
# Out:
# 'Amarjit'

# %%
ordered_numbers[2:-1]
# Out:
# [5, 13]
